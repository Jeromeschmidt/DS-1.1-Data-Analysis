# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('Datasets/startup.csv')
df
# Out:
#                                 name  category_list  funding_total_usd  \
# 0                             H2O.ai       Software          33.600000
# 1                           One Inc.         Mobile           1.150050
# 2                         1000 Corks       Software           0.040000
# 3                    1000museums.com       Software           6.795451
# 4                              Redox         Health           4.000000
# 5                           1010data       Software          35.000000
# 6                              10sec        Finance           1.600000
# 7                       10X Genomics     Technology          55.000000
# 8                            12 Labs         Health           0.935000
# 9                           121nexus         Health           0.794000
# 10                 1366 Technologies  Manufacturing          71.450000
# 11                         140 Proof      Marketing           5.500000
# ...

# %%
# funding_and_dates = df['funding_total_usd'] + df['founded_at']
funding_and_dates = pd.concat([df['funding_total_usd'], df['founded_at']], axis=1).sort_values('founded_at')

# %%
# funding_and_dates.plot.line('founded_at', 'funding_total_usd')
new_df = df.sort_values('founded_at')
new_df.plot('founded_at', 'funding_total_usd')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-78-c555157c237d> in <module>()
#       1 # funding_and_dates.plot.line('founded_at', 'funding_total_usd')
#       2 new_df = df.sort_values('founded_at')
# ----> 3 new_df.plot.xkcd('founded_at', 'funding_total_usd')
#       4 plt.show()
#
# AttributeError: 'FramePlotMethods' object has no attribute 'xkcd'

# %%
# ls = []
# for i in list(df_dropped['founded_at'].sort_values()):

# plt.figure(figsize = (20,5) )
# plt.plot(list(df_dropped['founed_at'].sort_values().unique()), ls, 'o')
df_dropped = df.dropna()

ls_software = []
for i in list(df_dropped['founded_at'].sort_values().unique()):
    ls_software.append(df_dropped[(df['founded_at'] == i) & (df_dropped['category_list'] == 'Software')]['funding_total_usd'])
# return ls_software
# Out:
# /Users/jeromeschmidt/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:10: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   # Remove the CWD from sys.path while we load stuff.

# %%
print(ls_software)
# Out:
# [5337     40.0
# 12820    28.0
# Name: funding_total_usd, dtype: float64, Series([], Name: funding_total_usd, dtype: float64), Series([], Name: funding_total_usd, dtype: float64), Series([], Name: funding_total_usd, dtype: float64), Series([], Name: funding_total_usd, dtype: float64), Series([], Name: funding_total_usd, dtype: float64), Series([], Name: funding_total_usd, dtype: float64), Series([], Name: funding_total_usd, dtype: float64), Series([], Name: funding_total_usd, dtype: float64), Series([], Name: funding_total_usd, dtype: float64), Series([], Name: funding_total_usd, dtype: float64), Series([], Name: funding_total_usd, dtype: float64), Series([], Name: funding_total_usd, dtype: float64), Series([], Name: funding_total_usd, dtype: float64), Series([], Name: funding_total_usd, dtype: float64), 9846    35.0
# ...
